# %% [markdown]
# ## Python functions to perform Visual Impact Assessment (VIA)
# Siddharth Ramavajjala <br>
# <i>Department of Geography, University of Wisconsin - Madison</i>

# %%
import geopandas as gpd
import pandas as pd
from shapely import Point, Polygon
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pyproj
from osgeo import gdal
import numpy as np
import rioxarray as rxr
from shapely import box
import whitebox
import rasterio as rio
from rasterio.plot import show,show_hist
wbt = whitebox.WhiteboxTools()
from osgeo import gdal

# %%
# Read United States Wind Turbine Database CSV file
# URL: https://www.sciencebase.gov/catalog/item/6001e327d34e592d8671fae0 (from USGS)
gdf = gpd.read_file("datasets/uswtdb.csv")
# Analyze and understand meaning columns
gdf.head(1)
# Out:
#    case_id    faa_ors           faa_asn usgs_pr_id eia_id t_state  \
# 0  3123233  40-097764  2021-WTW-7887-OE                        OK
#
#        t_county t_fips         p_name p_year  ... t_ttlh retrofit  \
# 0  Ellis County  40045  25 Mile Creek   2022  ...    180        0
#
#   retrofit_year t_conf_atr t_conf_loc t_img_date     t_img_srce       xlong  \
# 0                        1          3   1/4/2023  Digital Globe  -99.775963
#
#         ylat geometry
# 0  36.458096     None
#
# [1 rows x 28 columns]

# %%
# geom() return Point object based on longitude('xlong') and latitude('ylat')
def geom(x):
    """Function to create a Point geometry object and insert into GeoDatFrame"""
    return Point(x['xlong'], x['ylat'])
# Update the geometry column using lambda function
gdf["geometry"] = gdf.apply(lambda x: geom(x), axis=1)
# Print head to check if the column is updated correctly
gdf.head(1)
# Out:
#    case_id    faa_ors           faa_asn usgs_pr_id eia_id t_state  \
# 0  3123233  40-097764  2021-WTW-7887-OE                        OK
#
#        t_county t_fips         p_name p_year  ... t_ttlh retrofit  \
# 0  Ellis County  40045  25 Mile Creek   2022  ...    180        0
#
#   retrofit_year t_conf_atr t_conf_loc t_img_date     t_img_srce       xlong  \
# 0                        1          3   1/4/2023  Digital Globe  -99.775963
#
#         ylat                    geometry
# 0  36.458096  POINT (-99.77596 36.45810)
#
# [1 rows x 28 columns]

# %%
# gdf.crs property check whether a coordinate reference system (CRS) is assigned
if gdf.crs == None:
    print("No CRS")
# Out:
# No CRS

# %%
# If no CRS is assigned, use EPSG:4326 as long, lat values are in 3 Dimensional coordinate system
gdf = gdf.set_crs('epsg:4326')
# Use gdf.explore() to interactively map and view the point locations of wind turbines

# %%
# Print unique state values for scoping
gdf['t_state'].unique()
# Out:
# array(['OK', 'CA', 'IA', 'MA', 'OH', 'MN', 'IL', 'NE', 'WY', 'KS', 'PA',
#        'TX', 'IN', 'NC', 'NM', 'NH', 'MI', 'NY', 'ND', 'SD', 'CO', 'HI',
#        'PR', 'NJ', 'WV', 'OR', 'AK', 'WA', 'MT', 'ME', 'AR', 'RI', 'WI',
#        'MO', 'VT', 'TN', 'ID', 'UT', 'VA', 'MD', 'AZ', 'GU', 'CT', 'NV',
#        'DE'], dtype=object)

# %%
# Print count of unique counties to scope magnitude of dataset
gdf['t_county'].nunique()
# Out:
# 569

# %%
# Create a dictionary and store Wind Turbine count corresponding to each state
print("State \tWind Turbine Count")
wtb_dict = {}
for state in list(gdf['t_state'].unique()):
    print(f'{state}\t{gdf["t_state"].value_counts()[state]}')
    wtb_dict[state] = gdf["t_state"].value_counts()[state]
# Out:
# State 	Wind Turbine Count
# OK	5474
# CA	5989
# IA	6293
# MA	92
# OH	499
# MN	2744
# IL	3622
# NE	1523
# WY	1463
# KS	3962
# PA	752
# TX	18552
# IN	1614
# NC	105
# NM	1952
# NH	84
# MI	1637
# NY	1233
# ND	2095
# SD	1367
# CO	2835
# HI	129
# PR	63
# NJ	6
# WV	419
# OR	2122
# AK	142
# WA	1826
# MT	809
# ME	417
# AR	1
# RI	35
# WI	452
# MO	1107
# VT	73
# TN	18
# ID	541
# UT	208
# VA	2
# MD	80
# AZ	321
# GU	1
# CT	3
# NV	68
# DE	1

# %%
# Sort the dictionary values in ascending order and store them back
sorted_wtb_counts = sorted(wtb_dict.items(), key=lambda x:x[1])
wtb_dict = dict(sorted_wtb_counts)

# %%
# Print to view wind turbine count by state in ascending order
wtb_dict
# Out:
# {'AR': 1,
#  'GU': 1,
#  'DE': 1,
#  'VA': 2,
#  'CT': 3,
#  'NJ': 6,
#  'TN': 18,
#  'RI': 35,
#  'PR': 63,
#  'NV': 68,
#  'VT': 73,
#  'MD': 80,
#  'NH': 84,
#  'MA': 92,
#  'NC': 105,
#  'HI': 129,
#  'AK': 142,
#  'UT': 208,
#  'AZ': 321,
#  'ME': 417,
#  'WV': 419,
#  'WI': 452,
#  'OH': 499,
#  'ID': 541,
#  'PA': 752,
#  'MT': 809,
#  'MO': 1107,
#  'NY': 1233,
#  'SD': 1367,
#  'WY': 1463,
#  'NE': 1523,
#  'IN': 1614,
#  'MI': 1637,
#  'WA': 1826,
#  'NM': 1952,
#  'ND': 2095,
#  'OR': 2122,
#  'MN': 2744,
#  'CO': 2835,
#  'IL': 3622,
#  'KS': 3962,
#  'OK': 5474,
#  'CA': 5989,
#  'IA': 6293,
#  'TX': 18552}

# %% [markdown]
# Dictionary to Dataframe (<a href = "https://stackoverflow.com/questions/18837262/convert-python-dict-into-a-dataframem">Link</a>)

# %%
wind_turbines_df = pd.DataFrame(wtb_dict.items(), columns=['State','Turbines'])
wind_turbines_df.head(1)
# Out:
#   State  Turbines
# 0    AR         1

# %%
tot = wind_turbines_df['Turbines'].sum()
tot
# Out:
# 72731

# %%
wind_turbines_df['Share'] = wind_turbines_df['Turbines'].apply(lambda x: round((x/tot)*100,0))
wind_turbines_df.head(1)
# Out:
#   State  Turbines  Share
# 0    AR         1    0.0

# %%
share_mean = wind_turbines_df['Share'].mean()
share_mean = round(share_mean,2)
share_mean
# Out:
# 2.27

# %%
wind_turbines_above_mean = wind_turbines_df [wind_turbines_df['Share']>share_mean]

# %%
plt.rcParams['figure.figsize'] = [5, 4]
# Plot bar chart for ranking each state
plt.bar(wind_turbines_above_mean['State'], wind_turbines_above_mean['Turbines'], color='#31a354', edgecolor='#252525')
# Adjust the rotation angle to 90 degrees (To avoid label clutter)
plt.xticks(rotation=45)  
plt.title('Wind Turbines above mean share')
plt.xlabel('State name')
plt.ylabel('Turbine count')
# Show the plot
plt.show()

# %% [markdown]
# ### Wind Turbines in Texas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Blackjack Creek Project
# - Bee County, Texas

# %%
gdf_tx_aoi = gdf[(gdf['t_state']=='TX') & (gdf['t_county']=='Bee County') & (gdf['p_name']=='Blackjack Creek')]

# %%
gdf_tx_aoi.plot(marker="+")
plt.title("Wind Turbine locations")
plt.show()

# %%
gdf_tx_aoi.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7999050b8f2814592622e3f534941888 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7999050b8f2814592622e3f534941888&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7999050b8f2814592622e3f534941888 = L.map(
#                 &quot;map_7999050b8f2814592622e3f534941888&quot;,
#                 {
#                     center: [28.264711499999997, -97.51760100000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7999050b8f2814592622e3f534941888);
#
#
#
#
#
#             var tile_layer_6066b435cf25f86f2c21fa5888728326 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7999050b8f2814592622e3f534941888);
#
#
#             map_7999050b8f2814592622e3f534941888.fitBounds(
#                 [[28.221092, -97.573631], [28.308331, -97.461571]],
#                 {}
#             );
#
#
#         function geo_json_5c8b5831e61988c45db3df2b2c32467d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5c8b5831e61988c45db3df2b2c32467d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5c8b5831e61988c45db3df2b2c32467d_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_5c8b5831e61988c45db3df2b2c32467d_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5c8b5831e61988c45db3df2b2c32467d_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_5c8b5831e61988c45db3df2b2c32467d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5c8b5831e61988c45db3df2b2c32467d_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5c8b5831e61988c45db3df2b2c32467d = L.geoJson(null, {
#                 onEachFeature: geo_json_5c8b5831e61988c45db3df2b2c32467d_onEachFeature,
#
#                 style: geo_json_5c8b5831e61988c45db3df2b2c32467d_styler,
#                 pointToLayer: geo_json_5c8b5831e61988c45db3df2b2c32467d_pointToLayer
#         });
#
#         function geo_json_5c8b5831e61988c45db3df2b2c32467d_add (data) {
#             geo_json_5c8b5831e61988c45db3df2b2c32467d
#                 .addData(data)
#                 .addTo(map_7999050b8f2814592622e3f534941888);
#         }
#             geo_json_5c8b5831e61988c45db3df2b2c32467d_add({&quot;bbox&quot;: [-97.573631, 28.221092, -97.461571, 28.308331], &quot;features&quot;: [{&quot;bbox&quot;: [-97.565788, 28.285681, -97.565788, 28.285681], &quot;geometry&quot;: {&quot;coordinates&quot;: [-97.565788, 28.285681], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5071&quot;, &quot;properties&quot;: {&quot;case_id&quot;: &quot;3119713&quot;, &quot;eia_id&quot;: &quot;&quot;, &quot;faa_asn&quot;: &quot;2019-WTW-9999-OE&quot;, &quot;faa_ors&quot;: &quot;48-186736&quot;, &quot;p_cap&quot;: &quot;240&quot;, &quot;p_name&quot;: &quot;Blackjack Creek&quot;, &quot;p_tnum&quot;: &quot;50&quot;, &quot;p_year&quot;: &quot;2022&quot;, &quot;retrofit

# %%
print(f'Xmax:{gdf_tx_aoi["xlong"].max()} \tYmax:{gdf_tx_aoi["ylat"].max()} \nXmin:{gdf_tx_aoi["xlong"].min()} \tYmin:{gdf_tx_aoi["ylat"].min()}')
# Out:
# Xmax:-97.573631 	Ymax:28.308331
# Xmin:-97.461571 	Ymin:28.221092

# %% [markdown]
# Click here <a href = "https://apps.nationalmap.gov/downloader/#/">USGS TNM Downloader</a>  to download the DEM data using bounding box coordinates (aforementioned)

# %%
gdf_tx_aoi.columns.values
# Out:
# array(['case_id', 'faa_ors', 'faa_asn', 'usgs_pr_id', 'eia_id', 't_state',
#        't_county', 't_fips', 'p_name', 'p_year', 'p_tnum', 'p_cap',
#        't_manu', 't_model', 't_cap', 't_hh', 't_rd', 't_rsa', 't_ttlh',
#        'retrofit', 'retrofit_year', 't_conf_atr', 't_conf_loc',
#        't_img_date', 't_img_srce', 'xlong', 'ylat', 'geometry'],
#       dtype=object)

# %%
gdf_tx_aoi.head(1)
# Out:
#       case_id    faa_ors           faa_asn usgs_pr_id eia_id t_state  \
# 5071  3119713  48-186736  2019-WTW-9999-OE                        TX
#
#         t_county t_fips           p_name p_year  ... t_ttlh retrofit  \
# 5071  Bee County  48025  Blackjack Creek   2022  ...  185.5        0
#
#      retrofit_year t_conf_atr t_conf_loc t_img_date     t_img_srce  \
# 5071                        1          3  2/17/2022  Digital Globe
#
#            xlong       ylat                    geometry
# 5071  -97.565788  28.285681  POINT (-97.56579 28.28568)
#
# [1 rows x 28 columns]

# %%
dem = rxr.open_rasterio('datasets/USGS_13_n29w098_20211103.tif')
reproj_dem = dem.rio.reproject("EPSG:3857")

# %%
with rio.open('datasets/USGS_13_n29w098_20211103.tif') as dst:
    fig, ax = plt.subplots(figsize=(10,5))
    image_hidden = ax.imshow(dst.read()[0], cmap="gist_earth")
    fig.colorbar(image_hidden, ax=ax, cmap="gist_earth")
    show(dst,ax=ax, cmap = 'gist_earth')
    ax.set_title('Digital Elevation Model (1/3 arc)')
    plt.show()

# %%
with rio.open('datasets/USGS_13_n29w098_20211103.tif') as dst:
    meta = dst.meta.copy()
    output_crs = dst.crs.to_epsg()

# %%
meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'float32',
#  'nodata': -999999.0,
#  'width': 10812,
#  'height': 10812,
#  'count': 1,
#  'crs': CRS.from_epsg(4269),
#  'transform': Affine(9.259259269220166e-05, 0.0, -98.00055555629325,
#         0.0, -9.259259269220166e-05, 29.000555555895062)}

# %%
type(output_crs), output_crs
# Out:
# (int, 4269)

# %%
def min_coords(df):
    return (df['xlong'].min(), df['ylat'].min())
def max_coords(df):
    return (df['xlong'].max(), df['ylat'].max())

# %%
def reproj_coords(min_coords, max_coords, output_crs,input_crs=4326):
    source_crs = pyproj.CRS.from_epsg(input_crs)
    dest_crs = pyproj.CRS.from_epsg(output_crs)
    transformer = pyproj.Transformer.from_crs(source_crs, dest_crs, always_xy = True)
    xmin, ymin = transformer.transform(min_coords[0], min_coords[1])
    xmax, ymax = transformer.transform(max_coords[0], max_coords[1])
    return (xmin, ymin, xmax, ymax)

# %%
min_coords = min_coords(gdf_tx_aoi)
max_coords = max_coords(gdf_tx_aoi)

# %%
min_coords, max_coords
# Out:
# (('-97.461571', '28.221092'), ('-97.573631', '28.308331'))

# %%
reproj_coords(min_coords,max_coords,output_crs,4326)
# Out:
# (-97.46156572539842, 28.221094225596413, -97.57362590570015, 28.30833310252822)

# %%
gdf_tx_aoi = gdf_tx_aoi.to_crs('EPSG:4269')
gdf_tx_aoi.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - onshore and offshore: Canada - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon. Puerto Rico. United States (USA) - Alabama; Alaska; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Hawaii; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming. US Virgin Islands. British Virgin Islands.
# - bounds: (167.65, 14.92, -40.73, 86.45)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
gdf_tx_aoi.to_file('datasets/tx_aoi.shp')
# Out:
# C:\Users\Sidrcs\AppData\Local\Temp\ipykernel_17872\1591735196.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_tx_aoi.to_file('datasets/tx_aoi.shp')

# %% [markdown]
# ### Clipping raster to extent

# %%
bbox = reproj_coords(min_coords,max_coords,output_crs,4326)
bbox
# Out:
# (-97.46156572539842, 28.221094225596413, -97.57362590570015, 28.30833310252822)

# %%
def clip_raster(raster_in, raster_out, bbox, output_crs):
    input_data = rxr.open_rasterio(raster_in)
    clip_box = (box(*bbox))
    clip_data = input_data.rio.clip([clip_box])
    clip_data.rio.to_raster(raster_out)

# %%
clip_raster('datasets/USGS_13_n29w098_20211103.tif','datasets/clip_raster.tif', bbox, output_crs)

# %%
with rio.open('datasets/clip_raster.tif') as dst:
    show(dst, cmap = 'gist_earth')

# %% [markdown]
# Define the observer point coordinates
# - observer_x = -97.46156572539842
# - observer_y = 28.221094225596413

# %% [markdown]
# Set verbose off to avoid printing of text when using Whitebox (Source: <a href="https://www.whiteboxgeo.com/manual/wbt_book/python_scripting/tool_output.html">Click here</a>)

# %%
# Set working directory
wbt.set_working_dir(r'C:\Users\Sidrcs\Documents\Github\Visual_Impact_Assessment\datasets')
wbt.set_verbose_mode(False)
# Out:
# 0

# %%
# Whitebox viewshed uses a clip DEM raster, TX AoI Wind Turbine shapefile and creates a "Viewshed Raster" as an output
wbt.viewshed('clip_raster.tif', 'tx_aoi.shp', 'viewshed_out.tif', height=2.0)
# Out:
# 0

# %%
viewshed = rio.open('datasets/viewshed_out.tif')

# %%
viewshed.crs.to_epsg()
# Out:
# 4269

# %%
viewshed.crs.units_factor[0]
# Out:
# 'degree'

# %%
fig, ax = plt.subplots(figsize=(10,5))
image_hidden = ax.imshow(viewshed.read()[0], cmap="gist_yarg")
fig.colorbar(image_hidden, ax=ax, cmap="gist_yarg")
show(viewshed, ax=ax, cmap="gist_yarg")
ax.set_title("Viewshed for Wind Turbine locations")
plt.show()

# %%
meta_viewshed = viewshed.meta
meta_viewshed
# Out:
# {'driver': 'GTiff',
#  'dtype': 'float32',
#  'nodata': -999999.0,
#  'width': 1210,
#  'height': 942,
#  'count': 1,
#  'crs': CRS.from_epsg(4269),
#  'transform': Affine(9.259259269219985e-05, 0.0, -97.57361111138951,
#         0.0, -9.259259269220041e-05, 28.30833333292816)}

# %%
with rio.open('datasets/viewshed_out.tif') as dst:
    show_hist(dst, bins=30, stacked=False)

# %%
def mile2meter(mile):
    return (1609.34*mile)

# %%
gdf_tx_aoi = gdf_tx_aoi.to_crs(3857)
gdf_tx_aoi_buffer_half_mile = gdf_tx_aoi.geometry.buffer(mile2meter(0.5))
gdf_tx_aoi_buffer_four_mile = gdf_tx_aoi.geometry.buffer(mile2meter(4))
gdf_tx_aoi_buffer_ten_mile = gdf_tx_aoi.geometry.buffer(mile2meter(10))

# %%
geom_half_mile = gdf_tx_aoi_buffer_half_mile.geometry.unary_union
geom_four_mile = gdf_tx_aoi_buffer_four_mile.geometry.unary_union
geom_ten_mile = gdf_tx_aoi_buffer_ten_mile.geometry.unary_union

# %% [markdown]
# Trick used below is obtained from Stack Over Flow (<a href="https://gis.stackexchange.com/questions/285595/buffer-with-dissolve-geopandas-unary-union-multipolygon">link</a>)

# %%
s0 = gpd.GeoDataFrame(geometry=[geom_half_mile])
s1 = gpd.GeoDataFrame(geometry=[geom_four_mile])
s2 = gpd.GeoDataFrame(geometry=[geom_ten_mile])
sp = gdf_tx_aoi.geometry

# %%
fig, ax = plt.subplots(figsize=(5, 5))
s2.plot(ax=ax, facecolor='none', edgecolor='#e0ecf4')
s1.plot(ax=ax, facecolor='none', edgecolor='#9ebcda')
s0.plot(ax=ax, facecolor='none', edgecolor='#8856a7')
sp.plot(ax=ax, color='#31a354', alpha=0.5)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(5, 5))
s2.plot(ax=ax, facecolor='#e0ecf4', label='1')
s1.plot(ax=ax, facecolor='#9ebcda')
s0.plot(ax=ax, facecolor='#8856a7')
sp.plot(ax=ax, color='#f0f0f0', marker="+", label="Wind Turbine")

# Create custom legend handles
legend_handles = [
    mpatches.Patch(color='#e0ecf4',  label="10 mile"),
    mpatches.Patch(color='#9ebcda', label="4 mile"),
    mpatches.Patch(color='#8856a7', label="0.5 mile")
]

# Add a legend to the plot with custom handles
ax.legend(handles=legend_handles)
plt.title("Wind Turbine locations with Buffer")
plt.show()

# %% [markdown]
# ### Drafting Class and methods for <code>viawind</code> package

# %%
# Convert buffer units from mile to meter
def mile2meter(mile):
    """Function to convert and return buffer units from miles to meters"""
    return (1609.34*mile)
# Displays a plot with default colors
def visualize_wind_turbines_buffers(dataframe, title = "Wind Turbine locations with Buffer (EPSG:3857)"):
    """Function to visualize default buffer sizes with turbine point locations"""
    # Reads and reprojects wind turbine GeoDataFrame to EPSG:3857
    gdf_aoi = dataframe.to_crs(3857)
    # Create buffers for each point of sizes - 0.5, 4, 10 miles
    gdf_aoi_buffer_half_mile = gdf_aoi.geometry.buffer(mile2meter(0.5))
    gdf_aoi_buffer_four_mile = gdf_aoi.geometry.buffer(mile2meter(4))
    gdf_aoi_buffer_ten_mile = gdf_aoi.geometry.buffer(mile2meter(10))
    # Merge buffers into a single polygon and geometry is stored
    geom_half_mile = gdf_aoi_buffer_half_mile.geometry.unary_union
    geom_four_mile = gdf_aoi_buffer_four_mile.geometry.unary_union
    geom_ten_mile = gdf_aoi_buffer_ten_mile.geometry.unary_union
    # Each geometry is loaded as a GeoDataFrame
    s0 = gpd.GeoDataFrame(geometry=[geom_half_mile])
    s1 = gpd.GeoDataFrame(geometry=[geom_four_mile])
    s2 = gpd.GeoDataFrame(geometry=[geom_ten_mile])
    sp = gdf_aoi.geometry
    # Create a subplot and plot all geometries onto same plot
    fig, ax = plt.subplots(figsize=(10, 5))
    # Face colors are from Colorbrewer.org 
    s2.plot(ax=ax, facecolor='#e0ecf4', label='1')
    s1.plot(ax=ax, facecolor='#9ebcda')
    s0.plot(ax=ax, facecolor='#8856a7')
    sp.plot(ax=ax, color='#f0f0f0', marker="+", label="Wind Turbine")
    # Create custom legend handles
    legend_handles = [
        mpatches.Patch(color='#e0ecf4',  label="10 mile"),
        mpatches.Patch(color='#9ebcda', label="4 mile"),
        mpatches.Patch(color='#8856a7', label="0.5 mile")
    ]
    # Add a legend to the plot with custom handles
    ax.legend(handles=legend_handles)
    plt.title(title)
    plt.xlabel('Longitude (meter)')
    plt.ylabel('Latitude (meter)')
    plt.show()

# %%
# Creates a plot for viewshed with legend
def visualize_viewshed(viewshed_fpath, dataframe, cmap="gist_yarg", title="Viewshed for Wind Turbine locations"):
    """Function to create visualization of viewshed with legend"""
    viewshed = rio.open(viewshed_fpath)
    fig, ax = plt.subplots(figsize=(10,5))
    image_hidden = ax.imshow(viewshed.read()[0], cmap=cmap)
    fig.colorbar(image_hidden, ax=ax, cmap=cmap)
    df = dataframe.to_crs(viewshed.crs.to_epsg())
    df.plot(ax=ax, marker="+", color="gray")
    show(viewshed, ax=ax, cmap=cmap)
    ax.set_title(f"{title} (EPSG:{viewshed.crs.to_epsg()})")
    plt.xlabel(f'Longitude ({viewshed.crs.units_factor[0]})')
    plt.ylabel(f'Latitude ({viewshed.crs.units_factor[0]})')
    plt.show()

# %%
def visualize_dem(dem_fpath, cmap="gist_earth", title="Digital Elevation Model"):
    dst = rio.open(dem_fpath)
    fig, ax = plt.subplots(figsize=(10,5))
    image_hidden = ax.imshow(dst.read()[0], cmap=cmap)
    fig.colorbar(image_hidden, ax=ax, cmap=cmap)
    show(dst,ax=ax, cmap=cmap)
    ax.set_title(f'{title} (EPSG:{dst.crs.to_epsg()})')
    plt.xlabel(f'Longitude ({dst.crs.units_factor[0]})')
    plt.ylabel(f'Latitude ({dst.crs.units_factor[0]})')
    plt.show()

# %%
def visualize_wind_turbines(dataframe, title="Wind Turbine locations"):
    dataframe.plot(marker="+")
    plt.title(title)
    plt.xlabel('Longitude (meter)')
    plt.ylabel('Latitude (meter)')
    plt.show()

# %%
visualize_wind_turbines(dataframe=gdf_tx_aoi)

# %%
# Function to visualize wind turbines with buffers
visualize_wind_turbines_buffers(dataframe=gdf_tx_aoi)

# %%
visualize_dem(dem_fpath='datasets/USGS_13_n29w098_20211103.tif')

# %%
visualize_viewshed(viewshed_fpath='datasets/viewshed_out.tif', dataframe=gdf_tx_aoi, cmap='Purples')

# %%
visualize_viewshed(viewshed_fpath='datasets/viewshed_complete.tif', dataframe=gdf_tx_aoi, cmap='Purples')

# %% [markdown]
# ### Viewshed Analysis with Whitebox
# <code>gdal_translate -co COMPRESS=DEFLATE USGS_13_n29w098_20211103.tif USGS_DEM_deflate.tif</code> <br>
# The above code is used to deflate the DEM and it could be used with Whitebox

# %%
wbt.viewshed('USGS_DEM_deflate.tif', 'tx_aoi.shp', 'viewshed_complete.tif', height=2.0)
# Out:
# .\whitebox_tools.exe --run="Viewshed" --dem='USGS_DEM_deflate.tif' --stations='tx_aoi.shp' --output='viewshed_complete.tif' --height=2.0 -v --compress_rasters=False
#
# ****************************
# * Welcome to Viewshed      *
# * Powered by WhiteboxTools *
# * www.whiteboxgeo.com      *
# ****************************
# Reading data...
# Locating view stations: 0%
# Locating view stations: 2%
# Locating view stations: 4%
# Locating view stations: 7%
# Locating view stations: 9%
# Locating view stations: 12%
# Locating view stations: 14%
# Locating view stations: 17%
# Locating view stations: 19%
# Locating view stations: 21%
# Locating view stations: 24%
# Locating view stations: 26%
# Locating view stations: 29%
# Locating view stations: 31%
# Locating view stations: 34%
# Locating view stations: 36%
# Locating view stations: 39%
# Locating view stations: 41%
# Locating view stations: 43%
# Locating view stations: 46%
# Locating view stations: 48%
# Locating view stations: 51%
# Locating view stations: 53%
# Locating view stations: 56%
# Locating view stations: 58%
# Locating view stations: 60%
# Locating view stations: 63%
# Locating view stations: 65%
# Locating view stations: 68%
# Locating view stations: 70%
# Locating view stations: 73%
# Locating view stations: 75%
# Locating view stations: 78%
# Locating view stations: 80%
# Locating view stations: 82%
# Locating view stations: 85%
# Locating view stations: 87%
# Locating view stations: 90%
# Locating view stations: 92%
# Locating view stations: 95%
# Locating view stations: 97%
# Locating view stations: 100%
# Station 1 of 42
# Calculating view angle (Station 1 of 42): 0%
# Calculating view angle (Station 1 of 42): 1%
# Calculating view angle (Station 1 of 42): 2%
# Calculating view angle (Station 1 of 42): 3%
# Calculating view angle (Station 1 of 42): 4%
# Calculating view angle (Station 1 of 42): 5%
# Calculating view angle (Station 1 of 42): 6%
# Calculating view angle (Station 1 of 42): 7%
# Calculating view angle (Station 1 of 42): 8%
# Calculating view angle (Station 1 of 42): 9%
# Calculating view angle (Station 1 of 42): 10%
# Calculating view angle (Station 1 of 42): 11%
# Calculating view angle (Station 1 of 42): 12%
# Calculating view angle (Station 1 of 42): 13%
# Calculating view angle (Station 1 of 42): 14%
# Calculating view angle (Station 1 of 42): 15%
# Calculating view angle (Station 1 of 42): 16%
# Calculating view angle (Station 1 of 42): 17%
# Calculating view angle (Station 1 of 42): 18%
# Calculating view angle (Station 1 of 42): 19%
# Calculating view angle (Station 1 of 42): 20%
# Calculating view angle (Station 1 of 42): 21%
# Calculating view angle (Station 1 of 42): 22%
# Calculating view angle (Station 1 of 42): 23%
# Calculating view angle (Station 1 of 42): 24%
# Calculating view angle (Station 1 of 42): 25%
# Calculating view angle (Station 1 of 42): 26%
# Calculating view angle (Station 1 of 42): 27%
# Calculating view angle (Station 1 of 42): 28%
# Calculating view angle (Station 1 of 42): 29%
# Calculating view angle (Station 1 of 42): 30%
# Calculating view angle (Station 1 of 42): 31%
# Calculating view angle (Station 1 of 42): 32%
# Calculating view angle (Station 1 of 42): 33%
# Calculating view angle (Station 1 of 42): 34%
# Calculating view angle (Station 1 of 42): 35%
# Calculating view angle (Station 1 of 42): 36%
# Calculating view angle (Station 1 of 42): 37%
# Calculating view angle (Station 1 of 42): 38%
# Calculating view angle (Station 1 of 42): 39%
# Calculating view angle (Station 1 of 42): 40%
# Calculating view angle (Station 1 of 42): 41%
# Calculating view angle (Station 1 of 42): 42%
# Calculating view angle (Station 1 of 42): 43%
# Calculating view angle (Station 1 of 42): 44%
# Calculating view angle (Station 1 of 42): 45%
# Calculating view angle (Station 1 of 42): 46%
# Calculating view angle (Station 1 of 42): 47%
# Calculating view angle (Station 1 of 42): 48%
# Calculating view angle (Station 1 of 42): 49%
# Calculating view angle (Station 1 of 42): 50%
# Calculating view angle (Station 1 of 42): 51%
# Calculating view angle (Station 1 of 42): 52%
# Calculating view angle (Station 1 of 42): 53%
# Calculating view angle (Station 1 of 42): 54%
# Calculating view angle (Station 1 of 42): 55%
# Calculating view angle (Station 1 of 42): 56%
# Calculating view angle (Station 1 of 42): 57%
# Calculating view angle (Station 1 of 42): 58%
# Calculating view angle (Station 1 of 42): 59%
# Calculating view angle (Station 1 of 42): 60%
# Calculating view angle (Station 1 of 42): 61%
# Calculating view angle (Station 1 of 42): 62%
# Calculating view angle (Station 1 of 42): 63%
# Calculating view angle (Station 1 of 42): 64%
# Calculating view angle (Station 1 of 42): 65%
# Calculating view angle (Station 1 of 42): 66%
# Calculating view angle (Station 1 of 42): 67%
# Calculating view angle (Station 1 of 42): 68%
# Calculating view angle (Station 1 of 42): 69%
# Calculating view angle (Station 1 of 42): 70%
# Calculating view angle (Station 1 of 42): 71%
# Calculating view angle (Station 1 of 42): 72%
# Calculating view angle (Station 1 of 42): 73%
# Calculating view angle (Station 1 of 42): 74%
# Calculating view angle (Station 1 of 42): 75%
# Calculating view angle (Station 1 of 42): 76%
# Calculating view angle (Station 1 of 42): 77%
# Calculating view angle (Station 1 of 42): 78%
# Calculating view angle (Station 1 of 42): 79%
# Calculating view angle (Station 1 of 42): 80%
# Calculating view angle (Station 1 of 42): 81%
# Calculating view angle (Station 1 of 42): 82%
# Calculating view angle (Station 1 of 42): 83%
# Calculating view angle (Station 1 of 42): 84%
# Calculating view angle (Station 1 of 42): 85%
# Calculating view angle (Station 1 of 42): 86%
# Calculating view angle (Station 1 of 42): 87%
# Calculating view angle (Station 1 of 42): 88%
# Calculating view angle (Station 1 of 42): 89%
# Calculating view angle (Station 1 of 42): 90%
# Calculating view angle (Station 1 of 42): 91%
# Calculating view angle (Station 1 of 42): 92%
# Calculating view angle (Station 1 of 42): 93%
# Calculating view angle (Station 1 of 42): 94%
# Calculating view angle (Station 1 of 42): 95%
# Calculating view angle (Station 1 of 42): 96%
# Calculating view angle (Station 1 of 42): 97%
# Calculating view angle (Station 1 of 42): 98%
# Calculating view angle (Station 1 of 42): 99%
# Calculating view angle (Station 1 of 42): 100%
# Creating output: (Station 1 of 42): 0%
# Creating output: (Station 1 of 42): 1%
# Creating output: (Station 1 of 42): 2%
# Creating output: (Station 1 of 42): 3%
# Creating output: (Station 1 of 42): 4%
# Creating output: (Station 1 of 42): 5%
# Creating output: (Station 1 of 42): 6%
# Creating output: (Station 1 of 42): 7%
# Creating output: (Station 1 of 42): 8%
# Creating output: (Station 1 of 42): 9%
# Creating output: (Station 1 of 42): 10%
# Creating output: (Station 1 of 42): 11%
# Creating output: (Station 1 of 42): 12%
# Creating output: (Station 1 of 42): 13%
# Creating output: (Station 1 of 42): 14%
# Creating output: (Station 1 of 42): 15%
# Creating output: (Station 1 of 42): 16%
# Creating output: (Station 1 of 42): 17%
# Creating output: (Station 1 of 42): 18%
# Creating output: (Station 1 of 42): 19%
# Creating output: (Station 1 of 42): 20%
# Creating output: (Station 1 of 42): 21%
# Creating output: (Station 1 of 42): 22%
# Creating output: (Station 1 of 42): 23%
# Creating output: (Station 1 of 42): 24%
# Creating output: (Station 1 of 42): 25%
# Creating output: (Station 1 of 42): 26%
# Creating output: (Station 1 of 42): 27%
# Creating output: (Station 1 of 42): 28%
# Creating output: (Station 1 of 42): 29%
# Creating output: (Station 1 of 42): 30%
# Creating output: (Station 1 of 42): 31%
# Creating output: (Station 1 of 42): 32%
# Creating output: (Station 1 of 42): 33%
# Creating output: (Station 1 of 42): 34%
# Creating output: (Station 1 of 42): 35%
# Creating output: (Station 1 of 42): 36%
# Creating output: (Station 1 of 42): 37%
# Creating output: (Station 1 of 42): 38%
# Creating output: (Station 1 of 42): 39%
# Creating output: (Station 1 of 42): 40%
# Creating output: (Station 1 of 42): 41%
# Creating output: (Station 1 of 42): 42%
# Creating output: (Station 1 of 42): 43%
# Creating output: (Station 1 of 42): 44%
# Creating output: (Station 1 of 42): 45%
# Creating output: (Station 1 of 42): 46%
# Creating output: (Station 1 of 42): 47%
# Creating output: (Station 1 of 42): 48%
# Creating output: (Station 1 of 42): 49%
# Creating output: (Station 1 of 42): 50%
# Creating output: (Station 1 of 42): 51%
# Creating output: (Station 1 of 42): 52%
# Creating output: (Station 1 of 42): 53%
# Creating output: (Station 1 of 42): 54%
# Creating output: (Station 1 of 42): 55%
# Creating output: (Station 1 of 42): 56%
# Creating output: (Station 1 of 42): 57%
# Creating output: (Station 1 of 42): 58%
# Creating output: (Station 1 of 42): 59%
# Creating output: (Station 1 of 42): 60%
# Creating output: (Station 1 of 42): 61%
# Creating output: (Station 1 of 42): 62%
# Creating output: (Station 1 of 42): 63%
# Creating output: (Station 1 of 42): 64%
# Creating output: (Station 1 of 42): 65%
# Creating output: (Station 1 of 42): 66%
# Creating output: (Station 1 of 42): 67%
# Creating output: (Station 1 of 42): 68%
# Creating output: (Station 1 of 42): 69%
# Creating output: (Station 1 of 42): 70%
# Creating output: (Station 1 of 42): 71%
# Creating output: (Station 1 of 42): 72%
# Creating output: (Station 1 of 42): 73%
# Creating output: (Station 1 of 42): 74%
# Creating output: (Station 1 of 42): 75%
# Creating output: (Station 1 of 42): 76%
# Creating output: (Station 1 of 42): 77%
# Creating output: (Station 1 of 42): 78%
# Creating output: (Station 1 of 42): 79%
# Creating output: (Station 1 of 42): 80%
# Creating output: (Station 1 of 42): 81%
# Creating output: (Station 1 of 42): 82%
# Creating output: (Station 1 of 42): 83%
# Creating output: (Station 1 of 42): 84%
# Creating output: (Station 1 of 42): 85%
# Creating output: (Station 1 of 42): 86%
# Creating output: (Station 1 of 42): 87%
# Creating output: (Station 1 of 42): 88%
# Creating output: (Station 1 of 42): 89%
# Creating output: (Station 1 of 42): 90%
# Creating output: (Station 1 of 42): 91%
# Creating output: (Station 1 of 42): 92%
# Creating output: (Station 1 of 42): 93%
# Creating output: (Station 1 of 42): 94%
# Creating output: (Station 1 of 42): 95%
# Creating output: (Station 1 of 42): 96%
# Creating output: (Station 1 of 42): 97%
# Creating output: (Station 1 of 42): 98%
# Creating output: (Station 1 of 42): 99%
# Creating output: (Station 1 of 42): 100%
# Station 2 of 42
# Calculating view angle (Station 2 of 42): 0%
# Calculating view angle (Station 2 of 42): 1%
# Calculating view angle (Station 2 of 42): 2%
# Calculating view angle (Station 2 of 42): 3%
# Calculating view angle (Station 2 of 42): 4%
# Calculating view angle (Station 2 of 42): 5%
# Calculating view angle (Station 2 of 42): 6%
# Calculating view angle (Station 2 of 42): 7%
# Calculating view angle (Station 2 of 42): 8%
# Calculating view angle (Station 2 of 42): 9%
# Calculating view angle (Station 2 of 42): 10%
# Calculating view angle (Station 2 of 42): 11%
# Calculating view angle (Station 2 of 42): 12%
# Calculating view angle (Station 2 of 42): 13%
# Calculating view angle (Station 2 of 42): 14%
# Calculating view angle (Station 2 of 42): 15%
# Calculating view angle (Station 2 of 42): 16%
# Calculating view angle (Station 2 of 42): 17%
# Calculating view angle (Station 2 of 42): 18%
# Calculating view angle (Station 2 of 42): 19%
# Calculating view angle (Station 2 of 42): 20%
# Calculating view angle (Station 2 of 42): 21%
# Calculating view angle (Station 2 of 42): 22%
# Calculating view angle (Station 2 of 42): 23%
# Calculating view angle (Station 2 of 42): 24%
# Calculating view angle (Station 2 of 42): 25%
# Calculating view angle (Station 2 of 42): 26%
# Calculating view angle (Station 2 of 42): 27%
# Calculating view angle (Station 2 of 42): 28%
# Calculating view angle (Station 2 of 42): 29%
# Calculating view angle (Station 2 of 42): 30%
# Calculating view angle (Station 2 of 42): 31%
# Calculating view angle (Station 2 of 42): 32%
# Calculating view angle (Station 2 of 42): 33%
# Calculating view angle (Station 2 of 42): 34%
# Calculating view angle (Station 2 of 42): 35%
# Calculating view angle (Station 2 of 42): 36%
# Calculating view angle (Station 2 of 42): 37%
# Calculating view angle (Station 2 of 42): 38%
# Calculating view angle (Station 2 of 42): 39%
# Calculating view angle (Station 2 of 42): 40%
# Calculating view angle (Station 2 of 42): 41%
# Calculating view angle (Station 2 of 42): 42%
# Calculating view angle (Station 2 of 42): 43%
# Calculating view angle (Station 2 of 42): 44%
# Calculating view angle (Station 2 of 42): 45%
# Calculating view angle (Station 2 of 42): 46%
# Calculating view angle (Station 2 of 42): 47%
# Calculating view angle (Station 2 of 42): 48%
# Calculating view angle (Station 2 of 42): 49%
# Calculating view angle (Station 2 of 42): 50%
# Calculating view angle (Station 2 of 42): 51%
# Calculating view angle (Station 2 of 42): 52%
# Calculating view angle (Station 2 of 42): 53%
# Calculating view angle (Station 2 of 42): 54%
# Calculating view angle (Station 2 of 42): 55%
# Calculating view angle (Station 2 of 42): 56%
# Calculating view angle (Station 2 of 42): 57%
# Calculating view angle (Station 2 of 42): 58%
# Calculating view angle (Station 2 of 42): 59%
# Calculating view angle (Station 2 of 42): 60%
# Calculating view angle (Station 2 of 42): 61%
# Calculating view angle (Station 2 of 42): 62%
# Calculating view angle (Station 2 of 42): 63%
# Calculating view angle (Station 2 of 42): 64%
# Calculating view angle (Station 2 of 42): 65%
# Calculating view angle (Station 2 of 42): 66%
# Calculating view angle (Station 2 of 42): 67%
# Calculating view angle (Station 2 of 42): 68%
# Calculating view angle (Station 2 of 42): 69%
# Calculating view angle (Station 2 of 42): 70%
# Calculating view angle (Station 2 of 42): 71%
# Calculating view angle (Station 2 of 42): 72%
# Calculating view angle (Station 2 of 42): 73%
# Calculating view angle (Station 2 of 42): 74%
# Calculating view angle (Station 2 of 42): 75%
# Calculating view angle (Station 2 of 42): 76%
# Calculating view angle (Station 2 of 42): 77%
# Calculating view angle (Station 2 of 42): 78%
# Calculating view angle (Station 2 of 42): 79%
# Calculating view angle (Station 2 of 42): 80%
# Calculating view angle (Station 2 of 42): 81%
# Calculating view angle (Station 2 of 42): 82%
# Calculating view angle (Station 2 of 42): 83%
# Calculating view angle (Station 2 of 42): 84%
# Calculating view angle (Station 2 of 42): 85%
# Calculating view angle (Station 2 of 42): 86%
# Calculating view angle (Station 2 of 42): 87%
# Calculating view angle (Station 2 of 42): 88%
# Calculating view angle (Station 2 of 42): 89%
# Calculating view angle (Station 2 of 42): 90%
# Calculating view angle (Station 2 of 42): 91%
# Calculating view angle (Station 2 of 42): 92%
# Calculating view angle (Station 2 of 42): 93%
# Calculating view angle (Station 2 of 42): 94%
# Calculating view angle (Station 2 of 42): 95%
# Calculating view angle (Station 2 of 42): 96%
# Calculating view angle (Station 2 of 42): 97%
# Calculating view angle (Station 2 of 42): 98%
# Calculating view angle (Station 2 of 42): 99%
# Calculating view angle (Station 2 of 42): 100%
# Creating output: (Station 2 of 42): 0%
# Creating output: (Station 2 of 42): 1%
# Creating output: (Station 2 of 42): 2%
# Creating output: (Station 2 of 42): 3%
# Creating output: (Station 2 of 42): 4%
# Creating output: (Station 2 of 42): 5%
# Creating output: (Station 2 of 42): 6%
# Creating output: (Station 2 of 42): 7%
# Creating output: (Station 2 of 42): 8%
# Creating output: (Station 2 of 42): 9%
# Creating output: (Station 2 of 42): 10%
# Creating output: (Station 2 of 42): 11%
# Creating output: (Station 2 of 42): 12%
# Creating output: (Station 2 of 42): 13%
# Creating output: (Station 2 of 42): 14%
# Creating output: (Station 2 of 42): 15%
# Creating output: (Station 2 of 42): 16%
# Creating output: (Station 2 of 42): 17%
# Creating output: (Station 2 of 42): 18%
# Creating output: (Station 2 of 42): 19%
# Creating output: (Station 2 of 42): 20%
# Creating output: (Station 2 of 42): 21%
# Creating output: (Station 2 of 42): 22%
# Creating output: (Station 2 of 42): 23%
# Creating output: (Station 2 of 42): 24%
# Creating output: (Station 2 of 42): 25%
# Creating output: (Station 2 of 42): 26%
# Creating output: (Station 2 of 42): 27%
# Creating output: (Station 2 of 42): 28%
# Creating output: (Station 2 of 42): 29%
# Creating output: (Station 2 of 42): 30%
# Creating output: (Station 2 of 42): 31%
# Creating output: (Station 2 of 42): 32%
# Creating output: (Station 2 of 42): 33%
# Creating output: (Station 2 of 42): 34%
# Creating output: (Station 2 of 42): 35%
# Creating output: (Station 2 of 42): 36%
# Creating output: (Station 2 of 42): 37%
# Creating output: (Station 2 of 42): 38%
# Creating output: (Station 2 of 42): 39%
# Creating output: (Station 2 of 42): 40%
# Creating output: (Station 2 of 42): 41%
# Creating output: (Station 2 of 42): 42%
# Creating output: (Station 2 of 42): 43%
# Creating output: (Station 2 of 42): 44%
# Creating output: (Station 2 of 42): 45%
# Creating output: (Station 2 of 42): 46%
# Creating output: (Station 2 of 42): 47%
# Creating output: (Station 2 of 42): 48%
# Creating output: (Station 2 of 42): 49%
# Creating output: (Station 2 of 42): 50%
# Creating output: (Station 2 of 42): 51%
# Creating output: (Station 2 of 42): 52%
# Creating output: (Station 2 of 42): 53%
# Creating output: (Station 2 of 42): 54%
# Creating output: (Station 2 of 42): 55%
# Creating output: (Station 2 of 42): 56%
# Creating output: (Station 2 of 42): 57%
# Creating output: (Station 2 of 42): 58%
# Creating output: (Station 2 of 42): 59%
# Creating output: (Station 2 of 42): 60%
# Creating output: (Station 2 of 42): 61%
# Creating output: (Station 2 of 42): 62%
# Creating output: (Station 2 of 42): 63%
# Creating output: (Station 2 of 42): 64%
# Creating output: (Station 2 of 42): 65%
# Creating output: (Station 2 of 42): 66%
# Creating output: (Station 2 of 42): 67%
# Creating output: (Station 2 of 42): 68%
# Creating output: (Station 2 of 42): 69%
# Creating output: (Station 2 of 42): 70%
# Creating output: (Station 2 of 42): 71%
# Creating output: (Station 2 of 42): 72%
# Creating output: (Station 2 of 42): 73%
# Creating output: (Station 2 of 42): 74%
# Creating output: (Station 2 of 42): 75%
# Creating output: (Station 2 of 42): 76%
# Creating output: (Station 2 of 42): 77%
# Creating output: (Station 2 of 42): 78%
# Creating output: (Station 2 of 42): 79%
# Creating output: (Station 2 of 42): 80%
# Creating output: (Station 2 of 42): 81%
# Creating output: (Station 2 of 42): 82%
# Creating output: (Station 2 of 42): 83%
# Creating output: (Station 2 of 42): 84%
# Creating output: (Station 2 of 42): 85%
# Creating output: (Station 2 of 42): 86%
# Creating output: (Station 2 of 42): 87%
# Creating output: (Station 2 of 42): 88%
# Creating output: (Station 2 of 42): 89%
# Creating output: (Station 2 of 42): 90%
# Creating output: (Station 2 of 42): 91%
# Creating output: (Station 2 of 42): 92%
# Creating output: (Station 2 of 42): 93%
# Creating output: (Station 2 of 42): 94%
# Creating output: (Station 2 of 42): 95%
# Creating output: (Station 2 of 42): 96%
# Creating output: (Station 2 of 42): 97%
# Creating output: (Station 2 of 42): 98%
# Creating output: (Station 2 of 42): 99%
# Creating output: (Station 2 of 42): 100%
# Station 3 of 42
# Calculating view angle (Station 3 of 42): 0%
# Calculating view angle (Station 3 of 42): 1%
# Calculating view angle (Station 3 of 42): 2%
# Calculating view angle (Station 3 of 42): 3%
# Calculating view angle (Station 3 of 42): 4%
# Calculating view angle (Station 3 of 42): 5%
# Calculating view angle (Station 3 of 42): 6%
# Calculating view angle (Station 3 of 42): 7%
# Calculating view angle (Station 3 of 42): 8%
# Calculating view angle (Station 3 of 42): 9%
# Calculating view angle (Station 3 of 42): 10%
# Calculating view angle (Station 3 of 42): 11%
# Calculating view angle (Station 3 of 42): 12%
# Calculating view angle (Station 3 of 42): 13%
# Calculating view angle (Station 3 of 42): 14%
# Calculating view angle (Station 3 of 42): 15%
# Calculating view angle (Station 3 of 42): 16%
# Calculating view angle (Station 3 of 42): 17%
# Calculating view angle (Station 3 of 42): 18%
# Calculating view angle (Station 3 of 42): 19%
# Calculating view angle (Station 3 of 42): 20%
# Calculating view angle (Station 3 of 42): 21%
# Calculating view angle (Station 3 of 42): 22%
# Calculating view angle (Station 3 of 42): 23%
# Calculating view angle (Station 3 of 42): 24%
# Calculating view angle (Station 3 of 42): 25%
# Calculating view angle (Station 3 of 42): 26%
# Calculating view angle (Station 3 of 42): 27%
# Calculating view angle (Station 3 of 42): 28%
# Calculating view angle (Station 3 of 42): 29%
# Calculating view angle (Station 3 of 42): 30%
# Calculating view angle (Station 3 of 42): 31%
# Calculating view angle (Station 3 of 42): 32%
# Calculating view angle (Station 3 of 42): 33%
# Calculating view angle (Station 3 of 42): 34%
# Calculating view angle (Station 3 of 42): 35%
# Calculating view angle (Station 3 of 42): 36%
# Calculating view angle (Station 3 of 42): 37%
# Calculating view angle (Station 3 of 42): 38%
# Calculating view angle (Station 3 of 42): 39%
# Calculating view angle (Station 3 of 42): 40%
# Calculating view angle (Station 3 of 42): 41%
# Calculating view angle (Station 3 of 42): 42%
# Calculating view angle (Station 3 of 42): 43%
# Calculating view angle (Station 3 of 42): 44%
# Calculating view angle (Station 3 of 42): 45%
# Calculating view angle (Station 3 of 42): 46%
# Calculating view angle (Station 3 of 42): 47%
# Calculating view angle (Station 3 of 42): 48%
# Calculating view angle (Station 3 of 42): 49%
# Calculating view angle (Station 3 of 42): 50%
# Calculating view angle (Station 3 of 42): 51%
# Calculating view angle (Station 3 of 42): 52%
# Calculating view angle (Station 3 of 42): 53%
# Calculating view angle (Station 3 of 42): 54%
# Calculating view angle (Station 3 of 42): 55%
# Calculating view angle (Station 3 of 42): 56%
# Calculating view angle (Station 3 of 42): 57%
# Calculating view angle (Station 3 of 42): 58%
# Calculating view angle (Station 3 of 42): 59%
# Calculating view angle (Station 3 of 42): 60%
# Calculating view angle (Station 3 of 42): 61%
# Calculating view angle (Station 3 of 42): 62%
# Calculating view angle (Station 3 of 42): 63%
# Calculating view angle (Station 3 of 42): 64%
# Calculating view angle (Station 3 of 42): 65%
# Calculating view angle (Station 3 of 42): 66%
# Calculating view angle (Station 3 of 42): 67%
# Calculating view angle (Station 3 of 42): 68%
# Calculating view angle (Station 3 of 42): 69%
# Calculating view angle (Station 3 of 42): 70%
# Calculating view angle (Station 3 of 42): 71%
# Calculating view angle (Station 3 of 42): 72%
# Calculating view angle (Station 3 of 42): 73%
# Calculating view angle (Station 3 of 42): 74%
# Calculating view angle (Station 3 of 42): 75%
# Calculating view angle (Station 3 of 42): 76%
# Calculating view angle (Station 3 of 42): 77%
# Calculating view angle (Station 3 of 42): 78%
# Calculating view angle (Station 3 of 42): 79%
# Calculating view angle (Station 3 of 42): 80%
# Calculating view angle (Station 3 of 42): 81%
# Calculating view angle (Station 3 of 42): 82%
# Calculating view angle (Station 3 of 42): 83%
# Calculating view angle (Station 3 of 42): 84%
# Calculating view angle (Station 3 of 42): 85%
# Calculating view angle (Station 3 of 42): 86%
# Calculating view angle (Station 3 of 42): 87%
# Calculating view angle (Station 3 of 42): 88%
# Calculating view angle (Station 3 of 42): 89%
# Calculating view angle (Station 3 of 42): 90%
# Calculating view angle (Station 3 of 42): 91%
# Calculating view angle (Station 3 of 42): 92%
# Calculating view angle (Station 3 of 42): 93%
# Calculating view angle (Station 3 of 42): 94%
# Calculating view angle (Station 3 of 42): 95%
# Calculating view angle (Station 3 of 42): 96%
# Calculating view angle (Station 3 of 42): 97%
# Calculating view angle (Station 3 of 42): 98%
# Calculating view angle (Station 3 of 42): 99%
# Calculating view angle (Station 3 of 42): 100%
# Creating output: (Station 3 of 42): 0%
# Creating output: (Station 3 of 42): 1%
# Creating output: (Station 3 of 42): 2%
# Creating output: (Station 3 of 42): 3%
# Creating output: (Station 3 of 42): 4%
# Creating output: (Station 3 of 42): 5%
# Creating output: (Station 3 of 42): 6%
# Creating output: (Station 3 of 42): 7%
# Creating output: (Station 3 of 42): 8%
# Creating output: (Station 3 of 42): 9%
# Creating output: (Station 3 of 42): 10%
# Creating output: (Station 3 of 42): 11%
# Creating output: (Station 3 of 42): 12%
# Creating output: (Station 3 of 42): 13%
# Creating output: (Station 3 of 42): 14%
# Creating output: (Station 3 of 42): 15%
# Creating output: (Station 3 of 42): 16%
# Creating output: (Station 3 of 42): 17%
# Creating output: (Station 3 of 42): 18%
# Creating output: (Station 3 of 42): 19%
# Creating output: (Station 3 of 42): 20%
# Creating output: (Station 3 of 42): 21%
# Creating output: (Station 3 of 42): 22%
# Creating output: (Station 3 of 42): 23%
# Creating output: (Station 3 of 42): 24%
# Creating output: (Station 3 of 42): 25%
# Creating output: (Station 3 of 42): 26%
# Creating output: (Station 3 of 42): 27%
# Creating output: (Station 3 of 42): 28%
# Creating output: (Station 3 of 42): 29%
# Creating output: (Station 3 of 42): 30%
# Creating output: (Station 3 of 42): 31%
# Creating output: (Station 3 of 42): 32%
# Creating output: (Station 3 of 42): 33%
# Creating output: (Station 3 of 42): 34%
# Creating output: (Station 3 of 42): 35%
# Creating output: (Station 3 of 42): 36%
# Creating output: (Station 3 of 42): 37%
# Creating output: (Station 3 of 42): 38%
# Creating output: (Station 3 of 42): 39%
# Creating output: (Station 3 of 42): 40%
# Creating output: (Station 3 of 42): 41%
# Creating output: (Station 3 of 42): 42%
# Creating output: (Station 3 of 42): 43%
# Creating output: (Station 3 of 42): 44%
# Creating output: (Station 3 of 42): 45%
# Creating output: (Station 3 of 42): 46%
# Creating output: (Station 3 of 42): 47%
# Creating output: (Station 3 of 42): 48%
# Creating output: (Station 3 of 42): 49%
# Creating output: (Station 3 of 42): 50%
# Creating output: (Station 3 of 42): 51%
# Creating output: (Station 3 of 42): 52%
# Creating output: (Station 3 of 42): 53%
# Creating output: (Station 3 of 42): 54%
# Creating output: (Station 3 of 42): 55%
# Creating output: (Station 3 of 42): 56%
# Creating output: (Station 3 of 42): 57%
# Creating output: (Station 3 of 42): 58%
# Creating output: (Station 3 of 42): 59%
# Creating output: (Station 3 of 42): 60%
# Creating output: (Station 3 of 42): 61%
# Creating output: (Station 3 of 42): 62%
# Creating output: (Station 3 of 42): 63%
# Creating output: (Station 3 of 42): 64%
# Creating output: (Station 3 of 42): 65%
# Creating output: (Station 3 of 42): 66%
# Creating output: (Station 3 of 42): 67%
# Creating output: (Station 3 of 42): 68%
# Creating output: (Station 3 of 42): 69%
# Creating output: (Station 3 of 42): 70%
# Creating output: (Station 3 of 42): 71%
# Creating output: (Station 3 of 42): 72%
# Creating output: (Station 3 of 42): 73%
# Creating output: (Station 3 of 42): 74%
# Creating output: (Station 3 of 42): 75%
# Creating output: (Station 3 of 42): 76%
# Creating output: (Station 3 of 42): 77%
# Creating output: (Station 3 of 42): 78%
# Creating output: (Station 3 of 42): 79%
# Creating output: (Station 3 of 42): 80%
# Creating output: (Station 3 of 42): 81%
# Creating output: (Station 3 of 42): 82%
# Creating output: (Station 3 of 42): 83%
# Creating output: (Station 3 of 42): 84%
# Creating output: (Station 3 of 42): 85%
# Creating output: (Station 3 of 42): 86%
# Creating output: (Station 3 of 42): 87%
# Creating output: (Station 3 of 42): 88%
# Creating output: (Station 3 of 42): 89%
# Creating output: (Station 3 of 42): 90%
# Creating output: (Station 3 of 42): 91%
# Creating output: (Station 3 of 42): 92%
# Creating output: (Station 3 of 42): 93%
# Creating output: (Station 3 of 42): 94%
# Creating output: (Station 3 of 42): 95%
# Creating output: (Station 3 of 42): 96%
# Creating output: (Station 3 of 42): 97%
# Creating output: (Station 3 of 42): 98%
# Creating output: (Station 3 of 42): 99%
# Creating output: (Station 3 of 42): 100%
# Station 4 of 42
# Calculating view angle (Station 4 of 42): 0%
# Calculating view angle (Station 4 of 42): 1%
# Calculating view angle (Station 4 of 42): 2%
# Calculating view angle (Station 4 of 42): 3%
# Calculating view angle (Station 4 of 42): 4%
# Calculating view angle (Station 4 of 42): 5%
# Calculating view angle (Station 4 of 42): 6%
# Calculating view angle (Station 4 of 42): 7%
# Calculating view angle (Station 4 of 42): 8%
# Calculating view angle (Station 4 of 42): 9%
# Calculating view angle (Station 4 of 42): 10%
# Calculating view angle (Station 4 of 42): 11%
# Calculating view angle (Station 4 of 42): 12%
# Calculating view angle (Station 4 of 42): 13%
# Calculating view angle (Station 4 of 42): 14%
# Calculating view angle (Station 4 of 42): 15%
# Calculating view angle (Station 4 of 42): 16%
# Calculating view angle (Station 4 of 42): 17%
# Calculating view angle (Station 4 of 42): 18%
# Calculating view angle (Station 4 of 42): 19%
# Calculating view angle (Station 4 of 42): 20%
# Calculating view angle (Station 4 of 42): 21%
# Calculating view angle (Station 4 of 42): 22%
# Calculating view angle (Station 4 of 42): 23%
# Calculating view angle (Station 4 of 42): 24%
# Calculating view angle (Station 4 of 42): 25%
# Calculating view angle (Station 4 of 42): 26%
# Calculating view angle (Station 4 of 42): 27%
# Calculating view angle (Station 4 of 42): 28%
# Calculating view angle (Station 4 of 42): 29%
# Calculating view angle (Station 4 of 42): 30%
# Calculating view angle (Station 4 of 42): 31%
# Calculating view angle (Station 4 of 42): 32%
# Calculating view angle (Station 4 of 42): 33%
# Calculating view angle (Station 4 of 42): 34%
# Calculating view angle (Station 4 of 42): 35%
# Calculating view angle (Station 4 of 42): 36%
# Calculating view angle (Station 4 of 42): 37%
# Calculating view angle (Station 4 of 42): 38%
# Calculating view angle (Station 4 of 42): 39%
# Calculating view angle (Station 4 of 42): 40%
# Calculating view angle (Station 4 of 42): 41%
# Calculating view angle (Station 4 of 42): 42%
# Calculating view angle (Station 4 of 42): 43%
# Calculating view angle (Station 4 of 42): 44%
# Calculating view angle (Station 4 of 42): 45%
# Calculating view angle (Station 4 of 42): 46%
# Calculating view angle (Station 4 of 42): 47%
# Calculating view angle (Station 4 of 42): 48%
# Calculating view angle (Station 4 of 42): 49%
# Calculating view angle (Station 4 of 42): 50%
# Calculating view angle (Station 4 of 42): 51%
# Calculating view angle (Station 4 of 42): 52%
# Calculating view angle (Station 4 of 42): 53%
# Calculating view angle (Station 4 of 42): 54%
# Calculating view angle (Station 4 of 42): 55%
# Calculating view angle (Station 4 of 42): 56%
# Calculating view angle (Station 4 of 42): 57%
# Calculating view angle (Station 4 of 42): 58%
# Calculating view angle (Station 4 of 42): 59%
# Calculating view angle (Station 4 of 42): 60%
# Calculating view angle (Station 4 of 42): 61%
# Calculating view angle (Station 4 of 42): 62%
# Calculating view angle (Station 4 of 42): 63%
# Calculating view angle (Station 4 of 42): 64%
# Calculating view angle (Station 4 of 42): 65%
# Calculating view angle (Station 4 of 42): 66%
# Calculating view angle (Station 4 of 42): 67%
# Calculating view angle (Station 4 of 42): 68%
# Calculating view angle (Station 4 of 42): 69%
# Calculating view angle (Station 4 of 42): 70%
# Calculating view angle (Station 4 of 42): 71%
# Calculating view angle (Station 4 of 42): 72%
# Calculating view angle (Station 4 of 42): 73%
# Calculating view angle (Station 4 of 42): 74%
# Calculating view angle (Station 4 of 42): 75%
# Calculating view angle (Station 4 of 42): 76%
# Calculating view angle (Station 4 of 42): 77%
# Calculating view angle (Station 4 of 42): 78%
# Calculating view angle (Station 4 of 42): 79%
# Calculating view angle (Station 4 of 42): 80%
# Calculating view angle (Station 4 of 42): 81%
# Calculating view angle (Station 4 of 42): 82%
# Calculating view angle (Station 4 of 42): 83%
# Calculating view angle (Station 4 of 42): 84%
# Calculating view angle (Station 4 of 42): 85%
# Calculating view angle (Station 4 of 42): 86%
# Calculating view angle (Station 4 of 42): 87%
# Calculating view angle (Station 4 of 42): 88%
# Calculating view angle (Station 4 of 42): 89%
# Calculating view angle (Station 4 of 42): 90%
# Calculating view angle (Station 4 of 42): 91%
# Calculating view angle (Station 4 of 42): 92%
# Calculating view angle (Station 4 of 42): 93%
# Calculating view angle (Station 4 of 42): 94%
# Calculating view angle (Station 4 of 42): 95%
# Calculating view angle (Station 4 of 42): 96%
# Calculating view angle (Station 4 of 42): 97%
# Calculating view angle (Station 4 of 42): 98%
# Calculating view angle (Station 4 of 42): 99%
# Calculating view angle (Station 4 of 42): 100%
# Creating output: (Station 4 of 42): 0%
# Creating output: (Station 4 of 42): 1%
# Creating output: (Station 4 of 42): 2%
# Creating output: (Station 4 of 42): 3%
# Creating output: (Station 4 of 42): 4%
# Creating output: (Station 4 of 42): 5%
# Creating output: (Station 4 of 42): 6%
# Creating output: (Station 4 of 42): 7%
# Creating output: (Station 4 of 42): 8%
# Creating output: (Station 4 of 42): 9%
# Creating output: (Station 4 of 42): 10%
# Creating output: (Station 4 of 42): 11%
# Creating output: (Station 4 of 42): 12%
# Creating output: (Station 4 of 42): 13%
# Creating output: (Station 4 of 42): 14%
# Creating output: (Station 4 of 42): 15%
# Creating output: (Station 4 of 42): 16%
# Creating output: (Station 4 of 42): 17%
# Creating output: (Station 4 of 42): 18%
# Creating output: (Station 4 of 42): 19%
# Creating output: (Station 4 of 42): 20%
# Creating output: (Station 4 of 42): 21%
# Creating output: (Station 4 of 42): 22%
# Creating output: (Station 4 of 42): 23%
# Creating output: (Station 4 of 42): 24%
# Creating output: (Station 4 of 42): 25%
# Creating output: (Station 4 of 42): 26%
# Creating output: (Station 4 of 42): 27%
# Creating output: (Station 4 of 42): 28%
# Creating output: (Station 4 of 42): 29%
# Creating output: (Station 4 of 42): 30%
# Creating output: (Station 4 of 42): 31%
# Creating output: (Station 4 of 42): 32%
# Creating output: (Station 4 of 42): 33%
# Creating output: (Station 4 of 42): 34%
# Creating output: (Station 4 of 42): 35%
# Creating output: (Station 4 of 42): 36%
# Creating output: (Station 4 of 42): 37%
# Creating output: (Station 4 of 42): 38%
# Creating output: (Station 4 of 42): 39%
# Creating output: (Station 4 of 42): 40%
# Creating output: (Station 4 of 42): 41%
# Creating output: (Station 4 of 42): 42%
# Creating output: (Station 4 of 42): 43%
# Creating output: (Station 4 of 42): 44%
# Creating output: (Station 4 of 42): 45%
# Creating output: (Station 4 of 42): 46%
# Creating output: (Station 4 of 42): 47%
# Creating output: (Station 4 of 42): 48%
# Creating output: (Station 4 of 42): 49%
# Creating output: (Station 4 of 42): 50%
# Creating output: (Station 4 of 42): 51%
# Creating output: (Station 4 of 42): 52%
# Creating output: (Station 4 of 42): 53%
# Creating output: (Station 4 of 42): 54%
# Creating output: (Station 4 of 42): 55%
# Creating output: (Station 4 of 42): 56%
# Creating output: (Station 4 of 42): 57%
# Creating output: (Station 4 of 42): 58%
# Creating output: (Station 4 of 42): 59%
# Creating output: (Station 4 of 42): 60%
# Creating output: (Station 4 of 42): 61%
# Creating output: (Station 4 of 42): 62%
# Creating output: (Station 4 of 42): 63%
# Creating output: (Station 4 of 42): 64%
# Creating output: (Station 4 of 42): 65%
# Creating output: (Station 4 of 42): 66%
# Creating output: (Station 4 of 42): 67%
# Creating output: (Station 4 of 42): 68%
# Creating output: (Station 4 of 42): 69%
# Creating output: (Station 4 of 42): 70%
# Creating output: (Station 4 of 42): 71%
# Creating output: (Station 4 of 42): 72%
# Creating output: (Station 4 of 42): 73%
# Creating output: (Station 4 of 42): 74%
# Creating output: (Station 4 of 42): 75%
# Creating output: (Station 4 of 42): 76%
# Creating output: (Station 4 of 42): 77%
# Creating output: (Station 4 of 42): 78%
# Creating output: (Station 4 of 42): 79%
# Creating output: (Station 4 of 42): 80%
# Creating output: (Station 4 of 42): 81%
# Creating output: (Station 4 of 42): 82%
# Creating output: (Station 4 of 42): 83%
# Creating output: (Station 4 of 42): 84%
# Creating output: (Station 4 of 42): 85%
# Creating output: (Station 4 of 42): 86%
# Creating output: (Station 4 of 42): 87%
# Creating output: (Station 4 of 42): 88%
# Creating output: (Station 4 of 42): 89%
# Creating output: (Station 4 of 42): 90%
# Creating output: (Station 4 of 42): 91%
# Creating output: (Station 4 of 42): 92%
# Creating output: (Station 4 of 42): 93%
# Creating output: (Station 4 of 42): 94%
# Creating output: (Station 4 of 42): 95%
# Creating output: (Station 4 of 42): 96%
# Creating output: (Station 4 of 42): 97%
# Creating output: (Station 4 of 42): 98%
# Creating output: (Station 4 of 42): 99%
# Creating output: (Station 4 of 42): 100%
# Station 5 of 42
# Calculating view angle (Station 5 of 42): 0%
# Calculating view angle (Station 5 of 42): 1%
# Calculating view angle (Station 5 of 42): 2%
# Calculating view angle (Station 5 of 42): 3%
# Calculating view angle (Station 5 of 42): 4%
# Calculating view angle (Station 5 of 42): 5%
# Calculating view angle (Station 5 of 42): 6%
# Calculating view angle (Station 5 of 42): 7%
# Calculating view angle (Station 5 of 42): 8%
# Calculating view angle (Station 5 of 42): 9%
# Calculating view angle (Station 5 of 42): 10%
# Calculating view angle (Station 5 of 42): 11%
# Calculating view angle (Station 5 of 42): 12%
# Calculating view angle (Station 5 of 42): 13%
# Calculating view angle (Station 5 of 42): 14%
# Calculating view angle (Station 5 of 42): 15%
# Calculating view angle (Station 5 of 42): 16%
# Calculating view angle (Station 5 of 42): 17%
# Calculating view angle (Station 5 of 42): 18%
# Calculating view angle (Station 5 of 42): 19%
# Calculating view angle (Station 5 of 42): 20%
# Calculating view angle (Station 5 of 42): 21%
# Calculating view angle (Station 5 of 42): 22%
# Calculating view angle (Station 5 of 42): 23%
# Calculating view angle (Station 5 of 42): 24%
# Calculating view angle (Station 5 of 42): 25%
# Calculating view angle (Station 5 of 42): 26%
# Calculating view angle (Station 5 of 42): 27%
# Calculating view angle (Station 5 of 42): 28%
# Calculating view angle (Station 5 of 42): 29%
# Calculating view angle (Station 5 of 42): 30%
# Calculating view angle (Station 5 of 42): 31%
# Calculating view angle (Station 5 of 42): 32%
# Calculating view angle (Station 5 of 42): 33%
# Calculating view angle (Station 5 of 42): 34%
# Calculating view angle (Station 5 of 42): 35%
# Calculating view angle (Station 5 of 42): 36%
# Calculating view angle (Station 5 of 42): 37%
# Calculating view angle (Station 5 of 42): 38%
# Calculating view angle (Station 5 of 42): 39%
# Calculating view angle (Station 5 of 42): 40%
# Calculating view angle (Station 5 of 42): 41%
# Calculating view angle (Station 5 of 42): 42%
# Calculating view angle (Station 5 of 42): 43%
# Calculating view angle (Station 5 of 42): 44%
# Calculating view angle (Station 5 of 42): 45%
# Calculating view angle (Station 5 of 42): 46%
# Calculating view angle (Station 5 of 42): 47%
# Calculating view angle (Station 5 of 42): 48%
# Calculating view angle (Station 5 of 42): 49%
# Calculating view angle (Station 5 of 42): 50%
# Calculating view angle (Station 5 of 42): 51%
# Calculating view angle (Station 5 of 42): 52%
# Calculating view angle (Station 5 of 42): 53%
# Calculating view angle (Station 5 of 42): 54%
# Calculating view angle (Station 5 of 42): 55%
# Calculating view angle (Station 5 of 42): 56%
# Calculating view angle (Station 5 of 42): 57%
# Calculating view angle (Station 5 of 42): 58%
# Calculating view angle (Station 5 of 42): 59%
# Calculating view angle (Station 5 of 42): 60%
# Calculating view angle (Station 5 of 42): 61%
# Calculating view angle (Station 5 of 42): 62%
# Calculating view angle (Station 5 of 42): 63%
# Calculating view angle (Station 5 of 42): 64%
# Calculating view angle (Station 5 of 42): 65%
# Calculating view angle (Station 5 of 42): 66%
# Calculating view angle (Station 5 of 42): 67%
# Calculating view angle (Station 5 of 42): 68%
# Calculating view angle (Station 5 of 42): 69%
# Calculating view angle (Station 5 of 42): 70%
# Calculating view angle (Station 5 of 42): 71%
# Calculating view angle (Station 5 of 42): 72%
# Calculating view angle (Station 5 of 42): 73%
# Calculating view angle (Station 5 of 42): 74%
# Calculating view angle (Station 5 of 42): 75%
# Calculating view angle (Station 5 of 42): 76%
# Calculating view angle (Station 5 of 42): 77%
# Calculating view angle (Station 5 of 42): 78%
# Calculating view angle (Station 5 of 42): 79%
# Calculating view angle (Station 5 of 42): 80%
# Calculating view angle (Station 5 of 42): 81%
# Calculating view angle (Station 5 of 42): 82%
# Calculating view angle (Station 5 of 42): 83%
# Calculating view angle (Station 5 of 42): 84%
# Calculating view angle (Station 5 of 42): 85%
# Calculating view angle (Station 5 of 42): 86%
# Calculating view angle (Station 5 of 42): 87%
# Calculating view angle (Station 5 of 42): 88%
# Calculating view angle (Station 5 of 42): 89%
# Calculating view angle (Station 5 of 42): 90%
# Calculating view angle (Station 5 of 42): 91%
# Calculating view angle (Station 5 of 42): 92%
# Calculating view angle (Station 5 of 42): 93%
# Calculating view angle (Station 5 of 42): 94%
# Calculating view angle (Station 5 of 42): 95%
# Calculating view angle (Station 5 of 42): 96%
# Calculating view angle (Station 5 of 42): 97%
# Calculating view angle (Station 5 of 42): 98%
# Calculating view angle (Station 5 of 42): 99%
# Calculating view angle (Station 5 of 42): 100%
# Creating output: (Station 5 of 42): 0%
# Creating output: (Station 5 of 42): 1%
# Creating output: (Station 5 of 42): 2%
# Creating output: (Station 5 of 42): 3%
# Creating output: (Station 5 of 42): 4%
# Creating output: (Station 5 of 42): 5%
# Creating output: (Station 5 of 42): 6%
# Creating output: (Station 5 of 42): 7%
# Creating output: (Station 5 of 42): 8%
# Creating output: (Station 5 of 42): 9%
# Creating output: (Station 5 of 42): 10%
# Creating output: (Station 5 of 42): 11%
# Creating output: (Station 5 of 42): 12%
# Creating output: (Station 5 of 42): 13%
# Creating output: (Station 5 of 42): 14%
# Creating output: (Station 5 of 42): 15%
# Creating output: (Station 5 of 42): 16%
# Creating output: (Station 5 of 42): 17%
# Creating output: (Station 5 of 42): 18%
# Creating output: (Station 5 of 42): 19%
# Creating output: (Station 5 of 42): 20%
# Creating output: (Station 5 of 42): 21%
# Creating output: (Station 5 of 42): 22%
# Creating output: (Station 5 of 42): 23%
# Creating output: (Station 5 of 42): 24%
# Creating output: (Station 5 of 42): 25%
# Creating output: (Station 5 of 42): 26%
# Creating output: (Station 5 of 42): 27%
# Creating output: (Station 5 of 42): 28%
# Creating output: (Station 5 of 42): 29%
# Creating output: (Station 5 of 42): 30%
# Creating output: (Station 5 of 42): 31%
# Creating output: (Station 5 of 42): 32%
# Creating output: (Station 5 of 42): 33%
# Creating output: (Station 5 of 42): 34%
# Creating output: (Station 5 of 42): 35%
# Creating output: (Station 5 of 42): 36%
# Creating output: (Station 5 of 42): 37%
# Creating output: (Station 5 of 42): 38%
# Creating output: (Station 5 of 42): 39%
# Creating output: (Station 5 of 42): 40%
# Creating output: (Station 5 of 42): 41%
# Creating output: (Station 5 of 42): 42%
# Creating output: (Station 5 of 42): 43%
# Creating output: (Station 5 of 42): 44%
# Creating output: (Station 5 of 42): 45%
# Creating output: (Station 5 of 42): 46%
# Creating output: (Station 5 of 42): 47%
# Creating output: (Station 5 of 42): 48%
# Creating output: (Station 5 of 42): 49%
# Creating output: (Station 5 of 42): 50%
# Creating output: (Station 5 of 42): 51%
# Creating output: (Station 5 of 42): 52%
# Creating output: (Station 5 of 42): 53%
# Creating output: (Station 5 of 42): 54%
# Creating output: (Station 5 of 42): 55%
# Creating output: (Station 5 of 42): 56%
# Creating output: (Station 5 of 42): 57%
# Creating output: (Station 5 of 42): 58%
# Creating output: (Station 5 of 42): 59%
# Creating output: (Station 5 of 42): 60%
# Creating output: (Station 5 of 42): 61%
# Creating output: (Station 5 of 42): 62%
# Creating output: (Station 5 of 42): 63%
# Creating output: (Station 5 of 42): 64%
# Creating output: (Station 5 of 42): 65%
# Creating output: (Station 5 of 42): 66%
# Creating output: (Station 5 of 42): 67%
# Creating output: (Station 5 of 42): 68%
# Creating output: (Station 5 of 42): 69%
# Creating output: (Station 5 of 42): 70%
# Creating output: (Station 5 of 42): 71%
# Creating output: (Station 5 of 42): 72%
# Creating output: (Station 5 of 42): 73%
# Creating output: (Station 5 of 42): 74%
# Creating output: (Station 5 of 42): 75%
# Creating output: (Station 5 of 42): 76%
# Creating output: (Station 5 of 42): 77%
# Creating output: (Station 5 of 42): 78%
# Creating output: (Station 5 of 42): 79%
# Creating output: (Station 5 of 42): 80%
# Creating output: (Station 5 of 42): 81%
# Creating output: (Station 5 of 42): 82%
# Creating output: (Station 5 of 42): 83%
# Creating output: (Station 5 of 42): 84%
# Creating output: (Station 5 of 42): 85%
# Creating output: (Station 5 of 42): 86%
# Creating output: (Station 5 of 42): 87%
# Creating output: (Station 5 of 42): 88%
# Creating output: (Station 5 of 42): 89%
# Creating output: (Station 5 of 42): 90%
# Creating output: (Station 5 of 42): 91%
# Creating output: (Station 5 of 42): 92%
# Creating output: (Station 5 of 42): 93%
# Creating output: (Station 5 of 42): 94%
# Creating output: (Station 5 of 42): 95%
# Creating output: (Station 5 of 42): 96%
# Creating output: (Station 5 of 42): 97%
# Creating output: (Station 5 of 42): 98%
# Creating output: (Station 5 of 42): 99%
# Creating output: (Station 5 of 42): 100%
# Station 6 of 42
# Calculating view angle (Station 6 of 42): 0%
# Calculating view angle (Station 6 of 42): 1%
# Calculating view angle (Station 6 of 42): 2%
# Calculating view angle (Station 6 of 42): 3%
# Calculating view angle (Station 6 of 42): 4%
# Calculating view angle (Station 6 of 42): 5%
# Calculating view angle (Station 6 of 42): 6%
# Calculating view angle (Station 6 of 42): 7%
# Calculating view angle (Station 6 of 42): 8%
# Calculating view angle (Station 6 of 42): 9%
# Calculating view angle (Station 6 of 42): 10%
# Calculating view angle (Station 6 of 42): 11%
# Calculating view angle (Station 6 of 42): 12%
# Calculating view angle (Station 6 of 42): 13%
# Calculating view angle (Station 6 of 42): 14%
# Calculating view angle (Station 6 of 42): 15%
# Calculating view angle (Station 6 of 42): 16%
# Calculating view angle (Station 6 of 42): 17%
# Calculating view angle (Station 6 of 42): 18%
# Calculating view angle (Station 6 of 42): 19%
# Calculating view angle (Station 6 of 42): 20%
# Calculating view angle (Station 6 of 42): 21%
# Calculating view angle (Station 6 of 42): 22%
# Calculating view angle (Station 6 of 42): 23%
# Calculating view angle (Station 6 of 42): 24%
# Calculating view angle (Station 6 of 42): 25%
# Calculating view angle (Station 6 of 42): 26%
# Calculating view angle (Station 6 of 42): 27%
# Calculating view angle (Station 6 of 42): 28%
# Calculating view angle (Station 6 of 42): 29%
# Calculating view angle (Station 6 of 42): 30%
# Calculating view angle (Station 6 of 42): 31%
# Calculating view angle (Station 6 of 42): 32%
# Calculating view angle (Station 6 of 42): 33%
# Calculating view angle (Station 6 of 42): 34%
# Calculating view angle (Station 6 of 42): 35%
# Calculating view angle (Station 6 of 42): 36%
# Calculating view angle (Station 6 of 42): 37%
# Calculating view angle (Station 6 of 42): 38%
# Calculating view angle (Station 6 of 42): 39%
# Calculating view angle (Station 6 of 42): 40%
# Calculating view angle (Station 6 of 42): 41%
# Calculating view angle (Station 6 of 42): 42%
# Calculating view angle (Station 6 of 42): 43%
# Calculating view angle (Station 6 of 42): 44%
# Calculating view angle (Station 6 of 42): 45%
# Calculating view angle (Station 6 of 42): 46%
# Calculating view angle (Station 6 of 42): 47%
# Calculating view angle (Station 6 of 42): 48%
# Calculating view angle (Station 6 of 42): 49%
# Calculating view angle (Station 6 of 42): 50%
# Calculating view angle (Station 6 of 42): 51%
# Calculating view angle (Station 6 of 42): 52%
# Calculating view angle (Station 6 of 42): 53%
# Calculating view angle (Station 6 of 42): 54%
# Calculating view angle (Station 6 of 42): 55%
# Calculating view angle (Station 6 of 42): 56%
# Calculating view angle (Station 6 of 42): 57%
# Calculating view angle (Station 6 of 42): 58%
# Calculating view angle (Station 6 of 42): 59%
# Calculating view angle (Station 6 of 42): 60%
# Calculating view angle (Station 6 of 42): 61%
# Calculating view angle (Station 6 of 42): 62%
# Calculating view angle (Station 6 of 42): 63%
# Calculating view angle (Station 6 of 42): 64%
# Calculating view angle (Station 6 of 42): 65%
# ...
# Calculating view angle (Station 41 of 42): 40%
# Calculating view angle (Station 41 of 42): 41%
# Calculating view angle (Station 41 of 42): 42%
# Calculating view angle (Station 41 of 42): 43%
# Calculating view angle (Station 41 of 42): 44%
# Calculating view angle (Station 41 of 42): 45%
# Calculating view angle (Station 41 of 42): 46%
# Calculating view angle (Station 41 of 42): 47%
# Calculating view angle (Station 41 of 42): 48%
# Calculating view angle (Station 41 of 42): 49%
# Calculating view angle (Station 41 of 42): 50%
# Calculating view angle (Station 41 of 42): 51%
# Calculating view angle (Station 41 of 42): 52%
# Calculating view angle (Station 41 of 42): 53%
# Calculating view angle (Station 41 of 42): 54%
# Calculating view angle (Station 41 of 42): 55%
# Calculating view angle (Station 41 of 42): 56%
# Calculating view angle (Station 41 of 42): 57%
# Calculating view angle (Station 41 of 42): 58%
# Calculating view angle (Station 41 of 42): 59%
# Calculating view angle (Station 41 of 42): 60%
# Calculating view angle (Station 41 of 42): 61%
# Calculating view angle (Station 41 of 42): 62%
# Calculating view angle (Station 41 of 42): 63%
# Calculating view angle (Station 41 of 42): 64%
# Calculating view angle (Station 41 of 42): 65%
# Calculating view angle (Station 41 of 42): 66%
# Calculating view angle (Station 41 of 42): 67%
# Calculating view angle (Station 41 of 42): 68%
# Calculating view angle (Station 41 of 42): 69%
# Calculating view angle (Station 41 of 42): 70%
# Calculating view angle (Station 41 of 42): 71%
# Calculating view angle (Station 41 of 42): 72%
# Calculating view angle (Station 41 of 42): 73%
# Calculating view angle (Station 41 of 42): 74%
# Calculating view angle (Station 41 of 42): 75%
# Calculating view angle (Station 41 of 42): 76%
# Calculating view angle (Station 41 of 42): 77%
# Calculating view angle (Station 41 of 42): 78%
# Calculating view angle (Station 41 of 42): 79%
# Calculating view angle (Station 41 of 42): 80%
# Calculating view angle (Station 41 of 42): 81%
# Calculating view angle (Station 41 of 42): 82%
# Calculating view angle (Station 41 of 42): 83%
# Calculating view angle (Station 41 of 42): 84%
# Calculating view angle (Station 41 of 42): 85%
# Calculating view angle (Station 41 of 42): 86%
# Calculating view angle (Station 41 of 42): 87%
# Calculating view angle (Station 41 of 42): 88%
# Calculating view angle (Station 41 of 42): 89%
# Calculating view angle (Station 41 of 42): 90%
# Calculating view angle (Station 41 of 42): 91%
# Calculating view angle (Station 41 of 42): 92%
# Calculating view angle (Station 41 of 42): 93%
# Calculating view angle (Station 41 of 42): 94%
# Calculating view angle (Station 41 of 42): 95%
# Calculating view angle (Station 41 of 42): 96%
# Calculating view angle (Station 41 of 42): 97%
# Calculating view angle (Station 41 of 42): 98%
# Calculating view angle (Station 41 of 42): 99%
# Calculating view angle (Station 41 of 42): 100%
# Creating output: (Station 41 of 42): 0%
# Creating output: (Station 41 of 42): 1%
# Creating output: (Station 41 of 42): 2%
# Creating output: (Station 41 of 42): 3%
# Creating output: (Station 41 of 42): 4%
# Creating output: (Station 41 of 42): 5%
# Creating output: (Station 41 of 42): 6%
# Creating output: (Station 41 of 42): 7%
# Creating output: (Station 41 of 42): 8%
# Creating output: (Station 41 of 42): 9%
# Creating output: (Station 41 of 42): 10%
# Creating output: (Station 41 of 42): 11%
# Creating output: (Station 41 of 42): 12%
# Creating output: (Station 41 of 42): 13%
# Creating output: (Station 41 of 42): 14%
# Creating output: (Station 41 of 42): 15%
# Creating output: (Station 41 of 42): 16%
# Creating output: (Station 41 of 42): 17%
# Creating output: (Station 41 of 42): 18%
# Creating output: (Station 41 of 42): 19%
# Creating output: (Station 41 of 42): 20%
# Creating output: (Station 41 of 42): 21%
# Creating output: (Station 41 of 42): 22%
# Creating output: (Station 41 of 42): 23%
# Creating output: (Station 41 of 42): 24%
# Creating output: (Station 41 of 42): 25%
# Creating output: (Station 41 of 42): 26%
# Creating output: (Station 41 of 42): 27%
# Creating output: (Station 41 of 42): 28%
# Creating output: (Station 41 of 42): 29%
# Creating output: (Station 41 of 42): 30%
# Creating output: (Station 41 of 42): 31%
# Creating output: (Station 41 of 42): 32%
# Creating output: (Station 41 of 42): 33%
# Creating output: (Station 41 of 42): 34%
# Creating output: (Station 41 of 42): 35%
# Creating output: (Station 41 of 42): 36%
# Creating output: (Station 41 of 42): 37%
# Creating output: (Station 41 of 42): 38%
# Creating output: (Station 41 of 42): 39%
# Creating output: (Station 41 of 42): 40%
# Creating output: (Station 41 of 42): 41%
# Creating output: (Station 41 of 42): 42%
# Creating output: (Station 41 of 42): 43%
# Creating output: (Station 41 of 42): 44%
# Creating output: (Station 41 of 42): 45%
# Creating output: (Station 41 of 42): 46%
# Creating output: (Station 41 of 42): 47%
# Creating output: (Station 41 of 42): 48%
# Creating output: (Station 41 of 42): 49%
# Creating output: (Station 41 of 42): 50%
# Creating output: (Station 41 of 42): 51%
# Creating output: (Station 41 of 42): 52%
# Creating output: (Station 41 of 42): 53%
# Creating output: (Station 41 of 42): 54%
# Creating output: (Station 41 of 42): 55%
# Creating output: (Station 41 of 42): 56%
# Creating output: (Station 41 of 42): 57%
# Creating output: (Station 41 of 42): 58%
# Creating output: (Station 41 of 42): 59%
# Creating output: (Station 41 of 42): 60%
# Creating output: (Station 41 of 42): 61%
# Creating output: (Station 41 of 42): 62%
# Creating output: (Station 41 of 42): 63%
# Creating output: (Station 41 of 42): 64%
# Creating output: (Station 41 of 42): 65%
# Creating output: (Station 41 of 42): 66%
# Creating output: (Station 41 of 42): 67%
# Creating output: (Station 41 of 42): 68%
# Creating output: (Station 41 of 42): 69%
# Creating output: (Station 41 of 42): 70%
# Creating output: (Station 41 of 42): 71%
# Creating output: (Station 41 of 42): 72%
# Creating output: (Station 41 of 42): 73%
# Creating output: (Station 41 of 42): 74%
# Creating output: (Station 41 of 42): 75%
# Creating output: (Station 41 of 42): 76%
# Creating output: (Station 41 of 42): 77%
# Creating output: (Station 41 of 42): 78%
# Creating output: (Station 41 of 42): 79%
# Creating output: (Station 41 of 42): 80%
# Creating output: (Station 41 of 42): 81%
# Creating output: (Station 41 of 42): 82%
# Creating output: (Station 41 of 42): 83%
# Creating output: (Station 41 of 42): 84%
# Creating output: (Station 41 of 42): 85%
# Creating output: (Station 41 of 42): 86%
# Creating output: (Station 41 of 42): 87%
# Creating output: (Station 41 of 42): 88%
# Creating output: (Station 41 of 42): 89%
# Creating output: (Station 41 of 42): 90%
# Creating output: (Station 41 of 42): 91%
# Creating output: (Station 41 of 42): 92%
# Creating output: (Station 41 of 42): 93%
# Creating output: (Station 41 of 42): 94%
# Creating output: (Station 41 of 42): 95%
# Creating output: (Station 41 of 42): 96%
# Creating output: (Station 41 of 42): 97%
# Creating output: (Station 41 of 42): 98%
# Creating output: (Station 41 of 42): 99%
# Creating output: (Station 41 of 42): 100%
# Station 42 of 42
# Calculating view angle (Station 42 of 42): 0%
# Calculating view angle (Station 42 of 42): 1%
# Calculating view angle (Station 42 of 42): 2%
# Calculating view angle (Station 42 of 42): 3%
# Calculating view angle (Station 42 of 42): 4%
# Calculating view angle (Station 42 of 42): 5%
# Calculating view angle (Station 42 of 42): 6%
# Calculating view angle (Station 42 of 42): 7%
# Calculating view angle (Station 42 of 42): 8%
# Calculating view angle (Station 42 of 42): 9%
# Calculating view angle (Station 42 of 42): 10%
# Calculating view angle (Station 42 of 42): 11%
# Calculating view angle (Station 42 of 42): 12%
# Calculating view angle (Station 42 of 42): 13%
# Calculating view angle (Station 42 of 42): 14%
# Calculating view angle (Station 42 of 42): 15%
# Calculating view angle (Station 42 of 42): 16%
# Calculating view angle (Station 42 of 42): 17%
# Calculating view angle (Station 42 of 42): 18%
# Calculating view angle (Station 42 of 42): 19%
# Calculating view angle (Station 42 of 42): 20%
# Calculating view angle (Station 42 of 42): 21%
# Calculating view angle (Station 42 of 42): 22%
# Calculating view angle (Station 42 of 42): 23%
# Calculating view angle (Station 42 of 42): 24%
# Calculating view angle (Station 42 of 42): 25%
# Calculating view angle (Station 42 of 42): 26%
# Calculating view angle (Station 42 of 42): 27%
# Calculating view angle (Station 42 of 42): 28%
# Calculating view angle (Station 42 of 42): 29%
# Calculating view angle (Station 42 of 42): 30%
# Calculating view angle (Station 42 of 42): 31%
# Calculating view angle (Station 42 of 42): 32%
# Calculating view angle (Station 42 of 42): 33%
# Calculating view angle (Station 42 of 42): 34%
# Calculating view angle (Station 42 of 42): 35%
# Calculating view angle (Station 42 of 42): 36%
# Calculating view angle (Station 42 of 42): 37%
# Calculating view angle (Station 42 of 42): 38%
# Calculating view angle (Station 42 of 42): 39%
# Calculating view angle (Station 42 of 42): 40%
# Calculating view angle (Station 42 of 42): 41%
# Calculating view angle (Station 42 of 42): 42%
# Calculating view angle (Station 42 of 42): 43%
# Calculating view angle (Station 42 of 42): 44%
# Calculating view angle (Station 42 of 42): 45%
# Calculating view angle (Station 42 of 42): 46%
# Calculating view angle (Station 42 of 42): 47%
# Calculating view angle (Station 42 of 42): 48%
# Calculating view angle (Station 42 of 42): 49%
# Calculating view angle (Station 42 of 42): 50%
# Calculating view angle (Station 42 of 42): 51%
# Calculating view angle (Station 42 of 42): 52%
# Calculating view angle (Station 42 of 42): 53%
# Calculating view angle (Station 42 of 42): 54%
# Calculating view angle (Station 42 of 42): 55%
# Calculating view angle (Station 42 of 42): 56%
# Calculating view angle (Station 42 of 42): 57%
# Calculating view angle (Station 42 of 42): 58%
# Calculating view angle (Station 42 of 42): 59%
# Calculating view angle (Station 42 of 42): 60%
# Calculating view angle (Station 42 of 42): 61%
# Calculating view angle (Station 42 of 42): 62%
# Calculating view angle (Station 42 of 42): 63%
# Calculating view angle (Station 42 of 42): 64%
# Calculating view angle (Station 42 of 42): 65%
# Calculating view angle (Station 42 of 42): 66%
# Calculating view angle (Station 42 of 42): 67%
# Calculating view angle (Station 42 of 42): 68%
# Calculating view angle (Station 42 of 42): 69%
# Calculating view angle (Station 42 of 42): 70%
# Calculating view angle (Station 42 of 42): 71%
# Calculating view angle (Station 42 of 42): 72%
# Calculating view angle (Station 42 of 42): 73%
# Calculating view angle (Station 42 of 42): 74%
# Calculating view angle (Station 42 of 42): 75%
# Calculating view angle (Station 42 of 42): 76%
# Calculating view angle (Station 42 of 42): 77%
# Calculating view angle (Station 42 of 42): 78%
# Calculating view angle (Station 42 of 42): 79%
# Calculating view angle (Station 42 of 42): 80%
# Calculating view angle (Station 42 of 42): 81%
# Calculating view angle (Station 42 of 42): 82%
# Calculating view angle (Station 42 of 42): 83%
# Calculating view angle (Station 42 of 42): 84%
# Calculating view angle (Station 42 of 42): 85%
# Calculating view angle (Station 42 of 42): 86%
# Calculating view angle (Station 42 of 42): 87%
# Calculating view angle (Station 42 of 42): 88%
# Calculating view angle (Station 42 of 42): 89%
# Calculating view angle (Station 42 of 42): 90%
# Calculating view angle (Station 42 of 42): 91%
# Calculating view angle (Station 42 of 42): 92%
# Calculating view angle (Station 42 of 42): 93%
# Calculating view angle (Station 42 of 42): 94%
# Calculating view angle (Station 42 of 42): 95%
# Calculating view angle (Station 42 of 42): 96%
# Calculating view angle (Station 42 of 42): 97%
# Calculating view angle (Station 42 of 42): 98%
# Calculating view angle (Station 42 of 42): 99%
# Calculating view angle (Station 42 of 42): 100%
# Creating output: (Station 42 of 42): 0%
# Creating output: (Station 42 of 42): 1%
# Creating output: (Station 42 of 42): 2%
# Creating output: (Station 42 of 42): 3%
# Creating output: (Station 42 of 42): 4%
# Creating output: (Station 42 of 42): 5%
# Creating output: (Station 42 of 42): 6%
# Creating output: (Station 42 of 42): 7%
# Creating output: (Station 42 of 42): 8%
# Creating output: (Station 42 of 42): 9%
# Creating output: (Station 42 of 42): 10%
# Creating output: (Station 42 of 42): 11%
# Creating output: (Station 42 of 42): 12%
# Creating output: (Station 42 of 42): 13%
# Creating output: (Station 42 of 42): 14%
# Creating output: (Station 42 of 42): 15%
# Creating output: (Station 42 of 42): 16%
# Creating output: (Station 42 of 42): 17%
# Creating output: (Station 42 of 42): 18%
# Creating output: (Station 42 of 42): 19%
# Creating output: (Station 42 of 42): 20%
# Creating output: (Station 42 of 42): 21%
# Creating output: (Station 42 of 42): 22%
# Creating output: (Station 42 of 42): 23%
# Creating output: (Station 42 of 42): 24%
# Creating output: (Station 42 of 42): 25%
# Creating output: (Station 42 of 42): 26%
# Creating output: (Station 42 of 42): 27%
# Creating output: (Station 42 of 42): 28%
# Creating output: (Station 42 of 42): 29%
# Creating output: (Station 42 of 42): 30%
# Creating output: (Station 42 of 42): 31%
# Creating output: (Station 42 of 42): 32%
# Creating output: (Station 42 of 42): 33%
# Creating output: (Station 42 of 42): 34%
# Creating output: (Station 42 of 42): 35%
# Creating output: (Station 42 of 42): 36%
# Creating output: (Station 42 of 42): 37%
# Creating output: (Station 42 of 42): 38%
# Creating output: (Station 42 of 42): 39%
# Creating output: (Station 42 of 42): 40%
# Creating output: (Station 42 of 42): 41%
# Creating output: (Station 42 of 42): 42%
# Creating output: (Station 42 of 42): 43%
# Creating output: (Station 42 of 42): 44%
# Creating output: (Station 42 of 42): 45%
# Creating output: (Station 42 of 42): 46%
# Creating output: (Station 42 of 42): 47%
# Creating output: (Station 42 of 42): 48%
# Creating output: (Station 42 of 42): 49%
# Creating output: (Station 42 of 42): 50%
# Creating output: (Station 42 of 42): 51%
# Creating output: (Station 42 of 42): 52%
# Creating output: (Station 42 of 42): 53%
# Creating output: (Station 42 of 42): 54%
# Creating output: (Station 42 of 42): 55%
# Creating output: (Station 42 of 42): 56%
# Creating output: (Station 42 of 42): 57%
# Creating output: (Station 42 of 42): 58%
# Creating output: (Station 42 of 42): 59%
# Creating output: (Station 42 of 42): 60%
# Creating output: (Station 42 of 42): 61%
# Creating output: (Station 42 of 42): 62%
# Creating output: (Station 42 of 42): 63%
# Creating output: (Station 42 of 42): 64%
# Creating output: (Station 42 of 42): 65%
# Creating output: (Station 42 of 42): 66%
# Creating output: (Station 42 of 42): 67%
# Creating output: (Station 42 of 42): 68%
# Creating output: (Station 42 of 42): 69%
# Creating output: (Station 42 of 42): 70%
# Creating output: (Station 42 of 42): 71%
# Creating output: (Station 42 of 42): 72%
# Creating output: (Station 42 of 42): 73%
# Creating output: (Station 42 of 42): 74%
# Creating output: (Station 42 of 42): 75%
# Creating output: (Station 42 of 42): 76%
# Creating output: (Station 42 of 42): 77%
# Creating output: (Station 42 of 42): 78%
# Creating output: (Station 42 of 42): 79%
# Creating output: (Station 42 of 42): 80%
# Creating output: (Station 42 of 42): 81%
# Creating output: (Station 42 of 42): 82%
# Creating output: (Station 42 of 42): 83%
# Creating output: (Station 42 of 42): 84%
# Creating output: (Station 42 of 42): 85%
# Creating output: (Station 42 of 42): 86%
# Creating output: (Station 42 of 42): 87%
# Creating output: (Station 42 of 42): 88%
# Creating output: (Station 42 of 42): 89%
# Creating output: (Station 42 of 42): 90%
# Creating output: (Station 42 of 42): 91%
# Creating output: (Station 42 of 42): 92%
# Creating output: (Station 42 of 42): 93%
# Creating output: (Station 42 of 42): 94%
# Creating output: (Station 42 of 42): 95%
# Creating output: (Station 42 of 42): 96%
# Creating output: (Station 42 of 42): 97%
# Creating output: (Station 42 of 42): 98%
# Creating output: (Station 42 of 42): 99%
# Creating output: (Station 42 of 42): 100%
# Saving data...
# Output file written
# Elapsed Time (excluding I/O): 4min 56.306s
# 0
